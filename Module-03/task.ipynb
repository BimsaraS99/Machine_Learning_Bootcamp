# %% [markdown]
# # Simple Linear Regression from Scratch Using NumPy

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd

# %% [markdown]
# ### Load dataset

# %%
data = pd.read_csv("salary_data.csv")
print(data.head())
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
x = data['YearsExperience'].values
Y = data['Salary'].values

# %% [markdown]
# ### Linear Regression Model

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Find "a"

# %% [markdown]
# ### Find "b"

# %% [markdown]
# ### Y = a + bx

# %% [markdown]
# ### Predict the salary for 10 years of Experience

# %% [markdown]
# ### (Optional) Plot the Regression Line
